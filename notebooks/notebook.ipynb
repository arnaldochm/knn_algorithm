# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_iris
import seaborn as sns

# %%
X, y = load_iris(return_X_y=True, as_frame=True)

# %%
X
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=2011, test_size=0.2)
X_train
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 13                4.3               3.0                1.1               0.1
# 29                4.7               3.2                1.6               0.2
# 45                4.8               3.0                1.4               0.3
# 3                 4.6               3.1                1.5               0.2
# 64                5.6               2.9                3.6               1.3
# ..                ...               ...                ...               ...
# 99                5.7               2.8                4.1               1.3
# 59                5.2               2.7                3.9               1.4
# 40                5.0               3.5                1.3               0.3
# 77                6.7               3.0                5.0               1.7
# 43                5.0               3.5                1.6               0.6
#
# [120 rows x 4 columns]

# %%
df_train = X_train.copy()
df_train['specie'] = y_train.copy()
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 120 entries, 13 to 43
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  120 non-null    float64
#  1   sepal width (cm)   120 non-null    float64
#  2   petal length (cm)  120 non-null    float64
#  3   petal width (cm)   120 non-null    float64
#  4   specie             120 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 5.6 KB

# %%
sns.pairplot(data=df_train)
# Out:
# /home/arnaldoch/Documents/Bootcamp_Data_Science/Clases/knn_algorithm/.venv/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df_train.drop(['specie'],axis=1).corr()
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.086887           0.877693
# sepal width (cm)           -0.086887          1.000000          -0.388557
# petal length (cm)           0.877693         -0.388557           1.000000
# petal width (cm)            0.827499         -0.342166           0.965120
#
#                    petal width (cm)
# sepal length (cm)          0.827499
# sepal width (cm)          -0.342166
# petal length (cm)          0.965120
# petal width (cm)           1.000000

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
y_hat = model.predict(X_test)
print(f'Accuracy: {accuracy_score(y_test,y_hat):.2f}')
# Out:
# Accuracy: 0.93
